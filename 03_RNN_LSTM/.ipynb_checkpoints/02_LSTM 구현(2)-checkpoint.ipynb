# %% [markdown]
# # LSTM(Long Short Term Memory)
# https://dgkim5360.tistory.com/entry/understanding-long-short-term-memory-lstm-kr

# %% [markdown]
# ### 기울기 소실(Gradient Vanishing)과 기울기 폭발(Gradient Exploding)의 원인

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

N = 2   # 미니배치 크기
H = 3   # 은닉 상태 벡터의 차원 수
T = 20  # 시계열 데이터의 길이

dh = np.ones((N, H))

np.random.seed(3) # 재현할 수 있도록 난수의 시드 고정

Wh = np.random.randn(H, H)          # 기울기 폭발 (스칼라일 경우 Wh가 1보다 큰경 우)  --> NaN
# Wh = np.random.randn(H, H) * 0.5  # 기울기 소실 (스칼라일 경우 Wh가 1보다 작은 경우) --> 0
print('Wh:\n',Wh)


# Norm은 벡터의 길이 혹은 크기를 측정하는 방법(함수)이다
# L1 norm : 벡터의 각 요소의 절대값을 모두 합한 값
# L2 norm : 각 요소의 제곱을 모두 합하여 제곱근을 취한 값
# http://taewan.kim/post/norm/
norm_list = []
for t in range(T):
    dh = np.dot(dh, Wh.T)
    norm = np.sqrt(np.sum(dh**2)) / N
    norm_list.append(norm)

print(norm_list)

# 그래프 그리기
plt.plot(np.arange(len(norm_list)), norm_list)
plt.xticks([0, 4, 9, 14, 19], [1, 5, 10, 15, 20])
plt.xlabel('시간 크기(time step)')
plt.ylabel('노름(norm)')
plt.show()
# Out:
# Wh:
#  [[ 1.78862847  0.43650985  0.09649747]
#  [-1.8634927  -0.2773882  -0.35475898]
#  [-0.08274148 -0.62700068 -0.04381817]]
# [2.4684068094579303, 3.3357049741610365, 4.783279375373182, 6.279587332087612, 8.080776465019053, 10.251163032292936, 12.936063506609896, 16.276861327786712, 20.45482961834598, 25.688972842084684, 32.25315718048336, 40.48895641683869, 50.8244073070191, 63.79612654485427, 80.07737014308985, 100.5129892205125, 126.16331847536823, 158.35920648258823, 198.7710796761195, 249.495615421267]

# %% [markdown]
# ### 기울기 폭발 대책 : 기울기 클리핑(gradient cliping) 함수 구현
# https://wikidocs.net/61375

# %%
import numpy as np

dW1 = np.random.rand(3, 3) * 10
dW2 = np.random.rand(3, 3) * 10
print('dW1:\n',dW1)
print('dW2:\n',dW2)
grads = [dW1, dW2]
max_norm = 5.0  # threshold, 한계값

## nn_layers.py 에 추가한다
def clip_grads(grads, max_norm):
    total_norm = 0
    for grad in grads:  # L2 norm 구하기 , 제곱의 합의 제곱근
        total_norm += np.sum(grad ** 2)
    total_norm = np.sqrt(total_norm)

    rate = max_norm / (total_norm + 1e-6)
    if rate < 1: # total_norm 이 한계값(max_norm) 보다 클경우
        for grad in grads:
            grad *= rate

print('(dW1) before:', dW1.flatten())
clip_grads(grads, max_norm)
print('(dw1) after:', dW1.flatten())  # 값이 약간 줄어듦
# Out:
# dW1:
#  [[6.49144048 2.78487283 6.76254902]
#  [5.90862817 0.23981882 5.58854088]
#  [2.59252447 4.15101197 2.83525082]]
# dW2:
#  [[6.93137918 4.40453718 1.56867738]
#  [5.44649018 7.80314765 3.06363532]
#  [2.21957884 3.87971258 9.3638365 ]]
# (dW1) before: [6.49144048 2.78487283 6.76254902 5.90862817 0.23981882 5.58854088
#  2.59252447 4.15101197 2.83525082]
# (dw1) after: [1.49503731 0.64138134 1.55747605 1.36081038 0.05523244 1.28709139
#  0.59708178 0.95601551 0.65298384]

# %% [markdown]
# ### 기울기 소실 방지 : Gated RNN 인 LSTM(Long Short Term Memory)이나  GRU(Gated Recurrent Units ) 사용
# ### LSTM  : RNN에 기억 셀 𝐜<sub>𝐭</sub> 과 , f , g, i, o 게이트 추가

# %% [markdown]
# ### LSTM 클래스 구현

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

class LSTM:
    def __init__(self,Wx,Wh,b):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh),np.zeros_like(b)]
        self.cache = None
        
    def forward(self,x,h_prev,c_prev):
        Wx, Wh, b = self.params    # Wx : (D,4*H),  Wh: (H,4*H) 로 생성하여 입력됨
        N, H = h_prev.shape
        
        A = np.dot(x,Wx) + np.dot(h_prev,Wh) + b    # (N,4*H)
        
        # 동일한 사이즈 4개로 슬라이싱 : f,g,i,o
        f = A[:, :H]
        g = A[:, H:2*H]
        i = A[:, 2*H:3*H]
        o = A[:, 3*H:]
        
        f = sigmoid(f)
        g = np.tanh(g)
        i = sigmoid(i)
        o = sigmoid(o)
        
        c_next = f*c_prev + g*i
        h_next = o*np.tanh(c_next)
        
        self.cache = (x,h_prev,c_prev,c_next,f,g,i,o)
        
        return h_next,c_next
    
    def backward(self, dh_next,dc_next):
        Wx, Wh, b = self.params
        x,h_prev,c_prev,c_next,f,g,i,o = self.cache
        
        tanh_c_next = np.tanh(c_next)
        
        ds = dc_next + (o*dh_next)*(1 - tanh_c_next**2)
        
        dc_prev = ds * f
        
        df = ds * c_prev
        dg = ds * i
        di = ds * g
        do = dh_next * tanh_c_next
        
        # sigmoid 미분 : y*(1-y) 
        
        df *= f * (1 - f)
        di *= i * (1 - i)
        do *= o * (1 - o)
        
        # tanh 미분 : (1-y**2) 
        dg *= (1 - g**2)
        
        dA = np.hstack((df,dg,di,do))   # 수평으로 합치기 (slice의 역전파)
        
        dWh = np.dot(h_prev.T, dA)      # Matmul의 역전파
        dh_prev = np.dot(dA, Wh.T) 
        
        dWx = np.dot(x.T, dA)           # Matmul의 역전파
        dx = np.dot(dA, Wx.T)
        
        db = dA.sum(axis=0)             # repeat노드의 역전파 : sum()
        
        self.grads[0][...] = dWx
        self.grads[1][...] = dWh
        self.grads[2][...] = db
        
        return dx, dh_prev, dc_prev

# %% [markdown]
# ### Time LSTM 구현

# %%
class TimeLSTM:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh),np.zeros_like(b)]
        self.layers = None         
        
        self.h, self.c, self.dh = None,None,None 
        
        self.stateful = stateful   
    
    def set_state(self, h, c=None):
        self.h, self.c = h, c

    def reset_state(self):
        self.h, self.c = None, None
        
    # 순전파
    def forward(self, xs) :  # xs : (N,T,D)
        Wx, Wh, b = self.params
        N, T, D = xs.shape    
        H = Wh.shape[0]       # H : hidden size
        
        self.layers = []
        hs = np.empty((N,T,H),dtype='f') 
        
        if not self.stateful or self.h is None:  
            self.h = np.zeros((N,H),dtype='f')
        
        if not self.stateful or self.c is None:  
            self.c = np.zeros((N,H),dtype='f')
        
        for t in range(T):  
            layer = LSTM(*self.params) 
            self.h, self.c = layer.forward(xs[:,t,:],self.h, self.c) 
                                                     
            hs[:,t,:] = self.h
            self.layers.append(layer)
            
        return hs # 출력 , (N,T,H)  
    
    # 역전파
    def backward(self,dhs) :  # dhs : (N,T,H)
        Wx, Wh, b = self.params
        N, T, H = dhs.shape
        D = Wx.shape[0]   # Wx : (D,4*H)
        
        dxs = np.empty((N,T,D), dtype='f')
        dh, dc = 0,0
        grads = [0,0,0]
        
        for t in reversed(range(T)):
            layer = self.layers[t]
            dx,dh,dc = layer.backward(dhs[:,t,:] + dh, dc)
            dxs[:,t,:] = dx
        
            for i, grad in enumerate(layer.grads):  # 기울기를 합산
                grads[i] += grad

        for i, grad in enumerate(grads):
            self.grads[i][...] = grad
            
        self.dh = dh

        return dxs

# %% [markdown]
# ### LSTM을 사용한 언어 모델 : Rnnlm

# %%
import pickle

class Rnnlm:
    def __init__(self,vocab_size, wordvec_size, hidden_size):
        V,D,H = vocab_size, wordvec_size,hidden_size   # 10000, 100,100
        rn = np.random.randn
        
        # 가중치 초기화
        embed_W = (rn(V,D)/100).astype('f')
        
        lstm_Wx = (rn(D,4*H) / np.sqrt(D)).astype('f')  # Xavier(=Glorot) Initializer, https://gomguard.tistory.com/184
        lstm_Wh = (rn(H,4*H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4*H).astype('f')
        
        affine_W = (rn(H,V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')
        
        # 계층 생성
        self.layers = [
            TimeEmbedding(embed_W),
            TimeLSTM(lstm_Wx,lstm_Wh,lstm_b,stateful=True),
            TimeAffine(affine_W,affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layer = self.layers[1]
        
        # 모든 가중치와 기울기를 리스트에 모은다.
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads        
            
    def predict(self,xs):
        for layer in self.layers:
            xs = layer.forward(xs)
        return xs
    
    def forward(self, xs, ts):
        score = self.predict(xs)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout
            
    def reset_state(self):
        self.lstm_layer.reset_state()   

    def save_params(self, file_name='Rnnlm.pkl'):
        with open(file_name,'wb') as f:
            pickle.dump(self.params,f)
            
    def load_params(self, file_name='Rnnlm.pkl'):
        with open(file_name,'rb') as f:
            self.params = pickle.load(f)

# %% [markdown]
# ### 학습을 위한 코드

# %%
from nn_layers import sigmoid, SGD, TimeEmbedding, TimeAffine, TimeSoftmaxWithLoss, RnnlmTrainer
from dataset import ptb

# %%
# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 100
hidden_size = 100  # RNN의 은닉 상태 벡터의 원소 수
time_size = 5      # RNN을 펼치는 크기
lr = 20.0
# max_epoch = 4  #  약 30분 소요 , PPL : 약 136.07
max_epoch = 1
max_grad = 0.25  #  기울기 클리핑을 위한 threshold 값

# 학습 데이터 읽기 : 전체 데이터 사용
# https://raw.githubusercontent.com/tomsercu/lstm/master/data/ptb.train.txt
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test,_,_ = ptb.load_data('test')
vocab_size = len(word_to_id)
print(vocab_size,len(corpus))  # 10000 929589
xs = corpus[:-1]  # 입력
ts = corpus[1:]   # 출력（정답 레이블）
# Out:
# 10000 929589

# %%
# 모델 생성
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)


# 기울기 클리핑을 적용하여 학습
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad, eval_interval=20)
trainer.plot(ylim=(0,500))
# Out:
# | 에폭 1 |  반복 1 / 9295 | 시간 0[s] | 퍼플렉서티 9997.78
# | 에폭 1 |  반복 21 / 9295 | 시간 1[s] | 퍼플렉서티 2604.38
# | 에폭 1 |  반복 41 / 9295 | 시간 3[s] | 퍼플렉서티 1395.54
# | 에폭 1 |  반복 61 / 9295 | 시간 6[s] | 퍼플렉서티 1053.92
# | 에폭 1 |  반복 81 / 9295 | 시간 8[s] | 퍼플렉서티 913.57
# | 에폭 1 |  반복 101 / 9295 | 시간 10[s] | 퍼플렉서티 683.06
# | 에폭 1 |  반복 121 / 9295 | 시간 12[s] | 퍼플렉서티 842.63
# | 에폭 1 |  반복 141 / 9295 | 시간 14[s] | 퍼플렉서티 735.32
# | 에폭 1 |  반복 161 / 9295 | 시간 16[s] | 퍼플렉서티 748.70
# | 에폭 1 |  반복 181 / 9295 | 시간 18[s] | 퍼플렉서티 588.26
# | 에폭 1 |  반복 201 / 9295 | 시간 20[s] | 퍼플렉서티 549.61
# | 에폭 1 |  반복 221 / 9295 | 시간 22[s] | 퍼플렉서티 548.87
# | 에폭 1 |  반복 241 / 9295 | 시간 24[s] | 퍼플렉서티 605.48
# | 에폭 1 |  반복 261 / 9295 | 시간 26[s] | 퍼플렉서티 581.52
# | 에폭 1 |  반복 281 / 9295 | 시간 29[s] | 퍼플렉서티 508.78
# | 에폭 1 |  반복 301 / 9295 | 시간 31[s] | 퍼플렉서티 411.40
# | 에폭 1 |  반복 321 / 9295 | 시간 33[s] | 퍼플렉서티 493.95
# | 에폭 1 |  반복 341 / 9295 | 시간 35[s] | 퍼플렉서티 399.50
# | 에폭 1 |  반복 361 / 9295 | 시간 37[s] | 퍼플렉서티 447.31
# | 에폭 1 |  반복 381 / 9295 | 시간 39[s] | 퍼플렉서티 450.19
# | 에폭 1 |  반복 401 / 9295 | 시간 42[s] | 퍼플렉서티 466.94
# | 에폭 1 |  반복 421 / 9295 | 시간 43[s] | 퍼플렉서티 409.84
# | 에폭 1 |  반복 441 / 9295 | 시간 46[s] | 퍼플렉서티 390.73
# | 에폭 1 |  반복 461 / 9295 | 시간 48[s] | 퍼플렉서티 322.71
# | 에폭 1 |  반복 481 / 9295 | 시간 50[s] | 퍼플렉서티 359.85
# | 에폭 1 |  반복 501 / 9295 | 시간 53[s] | 퍼플렉서티 357.96
# | 에폭 1 |  반복 521 / 9295 | 시간 55[s] | 퍼플렉서티 402.17
# | 에폭 1 |  반복 541 / 9295 | 시간 58[s] | 퍼플렉서티 344.62
# | 에폭 1 |  반복 561 / 9295 | 시간 60[s] | 퍼플렉서티 342.85
# | 에폭 1 |  반복 581 / 9295 | 시간 63[s] | 퍼플렉서티 285.49
# | 에폭 1 |  반복 601 / 9295 | 시간 65[s] | 퍼플렉서티 373.45
# | 에폭 1 |  반복 621 / 9295 | 시간 67[s] | 퍼플렉서티 367.11
# | 에폭 1 |  반복 641 / 9295 | 시간 69[s] | 퍼플렉서티 308.52
# | 에폭 1 |  반복 661 / 9295 | 시간 71[s] | 퍼플렉서티 260.68
# | 에폭 1 |  반복 681 / 9295 | 시간 73[s] | 퍼플렉서티 261.47
# | 에폭 1 |  반복 701 / 9295 | 시간 76[s] | 퍼플렉서티 320.72
# | 에폭 1 |  반복 721 / 9295 | 시간 78[s] | 퍼플렉서티 300.91
# | 에폭 1 |  반복 741 / 9295 | 시간 80[s] | 퍼플렉서티 299.86
# | 에폭 1 |  반복 761 / 9295 | 시간 82[s] | 퍼플렉서티 342.07
# | 에폭 1 |  반복 781 / 9295 | 시간 84[s] | 퍼플렉서티 354.70
# | 에폭 1 |  반복 801 / 9295 | 시간 86[s] | 퍼플렉서티 284.61
# | 에폭 1 |  반복 821 / 9295 | 시간 88[s] | 퍼플렉서티 304.57
# | 에폭 1 |  반복 841 / 9295 | 시간 90[s] | 퍼플렉서티 286.25
# | 에폭 1 |  반복 861 / 9295 | 시간 91[s] | 퍼플렉서티 295.78
# | 에폭 1 |  반복 881 / 9295 | 시간 93[s] | 퍼플렉서티 290.65
# | 에폭 1 |  반복 901 / 9295 | 시간 95[s] | 퍼플렉서티 302.00
# | 에폭 1 |  반복 921 / 9295 | 시간 97[s] | 퍼플렉서티 311.05
# | 에폭 1 |  반복 941 / 9295 | 시간 99[s] | 퍼플렉서티 324.68
# | 에폭 1 |  반복 961 / 9295 | 시간 101[s] | 퍼플렉서티 335.21
# | 에폭 1 |  반복 981 / 9295 | 시간 102[s] | 퍼플렉서티 345.99
# | 에폭 1 |  반복 1001 / 9295 | 시간 104[s] | 퍼플렉서티 292.00
# | 에폭 1 |  반복 1021 / 9295 | 시간 106[s] | 퍼플렉서티 317.48
# | 에폭 1 |  반복 1041 / 9295 | 시간 108[s] | 퍼플렉서티 355.49
# | 에폭 1 |  반복 1061 / 9295 | 시간 110[s] | 퍼플렉서티 362.67
# | 에폭 1 |  반복 1081 / 9295 | 시간 112[s] | 퍼플렉서티 301.16
# | 에폭 1 |  반복 1101 / 9295 | 시간 114[s] | 퍼플렉서티 301.61
# | 에폭 1 |  반복 1121 / 9295 | 시간 116[s] | 퍼플렉서티 332.00
# | 에폭 1 |  반복 1141 / 9295 | 시간 118[s] | 퍼플렉서티 314.74
# | 에폭 1 |  반복 1161 / 9295 | 시간 120[s] | 퍼플렉서티 333.45
# | 에폭 1 |  반복 1181 / 9295 | 시간 122[s] | 퍼플렉서티 314.26
# | 에폭 1 |  반복 1201 / 9295 | 시간 124[s] | 퍼플렉서티 358.32
# | 에폭 1 |  반복 1221 / 9295 | 시간 126[s] | 퍼플렉서티 320.58
# | 에폭 1 |  반복 1241 / 9295 | 시간 128[s] | 퍼플렉서티 338.80
# | 에폭 1 |  반복 1261 / 9295 | 시간 130[s] | 퍼플렉서티 315.81
# | 에폭 1 |  반복 1281 / 9295 | 시간 132[s] | 퍼플렉서티 313.18
# | 에폭 1 |  반복 1301 / 9295 | 시간 134[s] | 퍼플렉서티 282.36
# | 에폭 1 |  반복 1321 / 9295 | 시간 136[s] | 퍼플렉서티 307.61
# | 에폭 1 |  반복 1341 / 9295 | 시간 138[s] | 퍼플렉서티 275.79
# | 에폭 1 |  반복 1361 / 9295 | 시간 141[s] | 퍼플렉서티 320.05
# | 에폭 1 |  반복 1381 / 9295 | 시간 143[s] | 퍼플렉서티 237.36
# | 에폭 1 |  반복 1401 / 9295 | 시간 145[s] | 퍼플렉서티 307.41
# | 에폭 1 |  반복 1421 / 9295 | 시간 147[s] | 퍼플렉서티 303.11
# | 에폭 1 |  반복 1441 / 9295 | 시간 149[s] | 퍼플렉서티 301.70
# | 에폭 1 |  반복 1461 / 9295 | 시간 151[s] | 퍼플렉서티 335.82
# | 에폭 1 |  반복 1481 / 9295 | 시간 153[s] | 퍼플렉서티 285.97
# | 에폭 1 |  반복 1501 / 9295 | 시간 155[s] | 퍼플렉서티 298.40
# | 에폭 1 |  반복 1521 / 9295 | 시간 158[s] | 퍼플렉서티 255.96
# | 에폭 1 |  반복 1541 / 9295 | 시간 160[s] | 퍼플렉서티 239.82
# | 에폭 1 |  반복 1561 / 9295 | 시간 162[s] | 퍼플렉서티 298.34
# | 에폭 1 |  반복 1581 / 9295 | 시간 164[s] | 퍼플렉서티 272.86
# | 에폭 1 |  반복 1601 / 9295 | 시간 166[s] | 퍼플렉서티 296.12
# | 에폭 1 |  반복 1621 / 9295 | 시간 168[s] | 퍼플렉서티 248.48
# | 에폭 1 |  반복 1641 / 9295 | 시간 170[s] | 퍼플렉서티 278.76
# | 에폭 1 |  반복 1661 / 9295 | 시간 172[s] | 퍼플렉서티 256.28
# | 에폭 1 |  반복 1681 / 9295 | 시간 174[s] | 퍼플렉서티 245.98
# | 에폭 1 |  반복 1701 / 9295 | 시간 176[s] | 퍼플렉서티 239.94
# | 에폭 1 |  반복 1721 / 9295 | 시간 178[s] | 퍼플렉서티 287.61
# | 에폭 1 |  반복 1741 / 9295 | 시간 180[s] | 퍼플렉서티 336.35
# | 에폭 1 |  반복 1761 / 9295 | 시간 182[s] | 퍼플렉서티 264.53
# | 에폭 1 |  반복 1781 / 9295 | 시간 184[s] | 퍼플렉서티 269.40
# | 에폭 1 |  반복 1801 / 9295 | 시간 185[s] | 퍼플렉서티 278.77
# | 에폭 1 |  반복 1821 / 9295 | 시간 187[s] | 퍼플렉서티 285.58
# | 에폭 1 |  반복 1841 / 9295 | 시간 189[s] | 퍼플렉서티 279.80
# | 에폭 1 |  반복 1861 / 9295 | 시간 191[s] | 퍼플렉서티 306.55
# | 에폭 1 |  반복 1881 / 9295 | 시간 193[s] | 퍼플렉서티 265.78
# | 에폭 1 |  반복 1901 / 9295 | 시간 194[s] | 퍼플렉서티 320.64
# | 에폭 1 |  반복 1921 / 9295 | 시간 196[s] | 퍼플렉서티 306.95
# | 에폭 1 |  반복 1941 / 9295 | 시간 198[s] | 퍼플렉서티 266.39
# | 에폭 1 |  반복 1961 / 9295 | 시간 200[s] | 퍼플렉서티 243.86
# | 에폭 1 |  반복 1981 / 9295 | 시간 202[s] | 퍼플렉서티 261.02
# | 에폭 1 |  반복 2001 / 9295 | 시간 203[s] | 퍼플렉서티 282.71
# | 에폭 1 |  반복 2021 / 9295 | 시간 205[s] | 퍼플렉서티 238.00
# | 에폭 1 |  반복 2041 / 9295 | 시간 207[s] | 퍼플렉서티 276.45
# | 에폭 1 |  반복 2061 / 9295 | 시간 209[s] | 퍼플렉서티 242.73
# | 에폭 1 |  반복 2081 / 9295 | 시간 211[s] | 퍼플렉서티 232.16
# | 에폭 1 |  반복 2101 / 9295 | 시간 213[s] | 퍼플렉서티 237.74
# | 에폭 1 |  반복 2121 / 9295 | 시간 215[s] | 퍼플렉서티 225.33
# | 에폭 1 |  반복 2141 / 9295 | 시간 217[s] | 퍼플렉서티 227.25
# | 에폭 1 |  반복 2161 / 9295 | 시간 219[s] | 퍼플렉서티 247.54
# | 에폭 1 |  반복 2181 / 9295 | 시간 220[s] | 퍼플렉서티 191.49
# | 에폭 1 |  반복 2201 / 9295 | 시간 222[s] | 퍼플렉서티 224.35
# | 에폭 1 |  반복 2221 / 9295 | 시간 224[s] | 퍼플렉서티 230.01
# | 에폭 1 |  반복 2241 / 9295 | 시간 226[s] | 퍼플렉서티 166.44
# | 에폭 1 |  반복 2261 / 9295 | 시간 227[s] | 퍼플렉서티 206.88
# | 에폭 1 |  반복 2281 / 9295 | 시간 229[s] | 퍼플렉서티 202.84
# | 에폭 1 |  반복 2301 / 9295 | 시간 231[s] | 퍼플렉서티 272.63
# | 에폭 1 |  반복 2321 / 9295 | 시간 233[s] | 퍼플렉서티 246.55
# | 에폭 1 |  반복 2341 / 9295 | 시간 235[s] | 퍼플렉서티 276.08
# | 에폭 1 |  반복 2361 / 9295 | 시간 237[s] | 퍼플렉서티 303.41
# | 에폭 1 |  반복 2381 / 9295 | 시간 239[s] | 퍼플렉서티 298.08
# | 에폭 1 |  반복 2401 / 9295 | 시간 241[s] | 퍼플렉서티 323.66
# | 에폭 1 |  반복 2421 / 9295 | 시간 242[s] | 퍼플렉서티 303.84
# | 에폭 1 |  반복 2441 / 9295 | 시간 244[s] | 퍼플렉서티 346.52
# | 에폭 1 |  반복 2461 / 9295 | 시간 246[s] | 퍼플렉서티 323.90
# | 에폭 1 |  반복 2481 / 9295 | 시간 248[s] | 퍼플렉서티 272.53
# | 에폭 1 |  반복 2501 / 9295 | 시간 250[s] | 퍼플렉서티 236.03
# | 에폭 1 |  반복 2521 / 9295 | 시간 252[s] | 퍼플렉서티 199.28
# | 에폭 1 |  반복 2541 / 9295 | 시간 254[s] | 퍼플렉서티 177.87
# | 에폭 1 |  반복 2561 / 9295 | 시간 256[s] | 퍼플렉서티 234.77
# | 에폭 1 |  반복 2581 / 9295 | 시간 258[s] | 퍼플렉서티 205.41
# | 에폭 1 |  반복 2601 / 9295 | 시간 260[s] | 퍼플렉서티 232.38
# | 에폭 1 |  반복 2621 / 9295 | 시간 261[s] | 퍼플렉서티 261.12
# | 에폭 1 |  반복 2641 / 9295 | 시간 263[s] | 퍼플렉서티 245.03
# | 에폭 1 |  반복 2661 / 9295 | 시간 265[s] | 퍼플렉서티 191.91
# | 에폭 1 |  반복 2681 / 9295 | 시간 267[s] | 퍼플렉서티 205.64
# | 에폭 1 |  반복 2701 / 9295 | 시간 269[s] | 퍼플렉서티 247.00
# | 에폭 1 |  반복 2721 / 9295 | 시간 272[s] | 퍼플렉서티 236.12
# | 에폭 1 |  반복 2741 / 9295 | 시간 274[s] | 퍼플렉서티 293.77
# | 에폭 1 |  반복 2761 / 9295 | 시간 275[s] | 퍼플렉서티 269.43
# | 에폭 1 |  반복 2781 / 9295 | 시간 277[s] | 퍼플렉서티 252.46
# | 에폭 1 |  반복 2801 / 9295 | 시간 279[s] | 퍼플렉서티 205.09
# | 에폭 1 |  반복 2821 / 9295 | 시간 281[s] | 퍼플렉서티 237.73
# | 에폭 1 |  반복 2841 / 9295 | 시간 283[s] | 퍼플렉서티 193.93
# | 에폭 1 |  반복 2861 / 9295 | 시간 285[s] | 퍼플렉서티 213.10
# | 에폭 1 |  반복 2881 / 9295 | 시간 287[s] | 퍼플렉서티 237.49
# | 에폭 1 |  반복 2901 / 9295 | 시간 288[s] | 퍼플렉서티 274.29
# | 에폭 1 |  반복 2921 / 9295 | 시간 290[s] | 퍼플렉서티 252.02
# | 에폭 1 |  반복 2941 / 9295 | 시간 292[s] | 퍼플렉서티 223.45
# | 에폭 1 |  반복 2961 / 9295 | 시간 294[s] | 퍼플렉서티 253.62
# | 에폭 1 |  반복 2981 / 9295 | 시간 296[s] | 퍼플렉서티 254.32
# | 에폭 1 |  반복 3001 / 9295 | 시간 298[s] | 퍼플렉서티 215.91
# | 에폭 1 |  반복 3021 / 9295 | 시간 300[s] | 퍼플렉서티 191.60
# | 에폭 1 |  반복 3041 / 9295 | 시간 302[s] | 퍼플렉서티 247.68
# | 에폭 1 |  반복 3061 / 9295 | 시간 304[s] | 퍼플렉서티 211.11
# | 에폭 1 |  반복 3081 / 9295 | 시간 306[s] | 퍼플렉서티 237.18
# | 에폭 1 |  반복 3101 / 9295 | 시간 308[s] | 퍼플렉서티 209.39
# | 에폭 1 |  반복 3121 / 9295 | 시간 310[s] | 퍼플렉서티 239.85
# | 에폭 1 |  반복 3141 / 9295 | 시간 311[s] | 퍼플렉서티 242.24
# | 에폭 1 |  반복 3161 / 9295 | 시간 313[s] | 퍼플렉서티 237.52
# | 에폭 1 |  반복 3181 / 9295 | 시간 315[s] | 퍼플렉서티 189.90
# | 에폭 1 |  반복 3201 / 9295 | 시간 318[s] | 퍼플렉서티 251.16
# | 에폭 1 |  반복 3221 / 9295 | 시간 320[s] | 퍼플렉서티 246.05
# | 에폭 1 |  반복 3241 / 9295 | 시간 322[s] | 퍼플렉서티 242.78
# | 에폭 1 |  반복 3261 / 9295 | 시간 323[s] | 퍼플렉서티 249.34
# | 에폭 1 |  반복 3281 / 9295 | 시간 325[s] | 퍼플렉서티 238.70
# | 에폭 1 |  반복 3301 / 9295 | 시간 327[s] | 퍼플렉서티 226.47
# | 에폭 1 |  반복 3321 / 9295 | 시간 329[s] | 퍼플렉서티 214.85
# | 에폭 1 |  반복 3341 / 9295 | 시간 331[s] | 퍼플렉서티 190.59
# | 에폭 1 |  반복 3361 / 9295 | 시간 334[s] | 퍼플렉서티 176.48
# | 에폭 1 |  반복 3381 / 9295 | 시간 336[s] | 퍼플렉서티 200.31
# | 에폭 1 |  반복 3401 / 9295 | 시간 338[s] | 퍼플렉서티 221.34
# | 에폭 1 |  반복 3421 / 9295 | 시간 340[s] | 퍼플렉서티 217.88
# | 에폭 1 |  반복 3441 / 9295 | 시간 342[s] | 퍼플렉서티 281.40
# | 에폭 1 |  반복 3461 / 9295 | 시간 344[s] | 퍼플렉서티 261.71
# | 에폭 1 |  반복 3481 / 9295 | 시간 346[s] | 퍼플렉서티 258.95
# | 에폭 1 |  반복 3501 / 9295 | 시간 349[s] | 퍼플렉서티 225.32
# | 에폭 1 |  반복 3521 / 9295 | 시간 351[s] | 퍼플렉서티 300.01
# | 에폭 1 |  반복 3541 / 9295 | 시간 353[s] | 퍼플렉서티 278.79
# | 에폭 1 |  반복 3561 / 9295 | 시간 355[s] | 퍼플렉서티 273.01
# | 에폭 1 |  반복 3581 / 9295 | 시간 357[s] | 퍼플렉서티 213.83
# | 에폭 1 |  반복 3601 / 9295 | 시간 360[s] | 퍼플렉서티 207.68
# | 에폭 1 |  반복 3621 / 9295 | 시간 362[s] | 퍼플렉서티 209.46
# | 에폭 1 |  반복 3641 / 9295 | 시간 364[s] | 퍼플렉서티 184.39
# | 에폭 1 |  반복 3661 / 9295 | 시간 366[s] | 퍼플렉서티 201.24
# | 에폭 1 |  반복 3681 / 9295 | 시간 369[s] | 퍼플렉서티 243.70
# | 에폭 1 |  반복 3701 / 9295 | 시간 371[s] | 퍼플렉서티 216.63
# | 에폭 1 |  반복 3721 / 9295 | 시간 373[s] | 퍼플렉서티 193.13
# | 에폭 1 |  반복 3741 / 9295 | 시간 375[s] | 퍼플렉서티 273.04
# | 에폭 1 |  반복 3761 / 9295 | 시간 378[s] | 퍼플렉서티 285.44
# | 에폭 1 |  반복 3781 / 9295 | 시간 380[s] | 퍼플렉서티 286.92
# | 에폭 1 |  반복 3801 / 9295 | 시간 382[s] | 퍼플렉서티 281.82
# | 에폭 1 |  반복 3821 / 9295 | 시간 384[s] | 퍼플렉서티 214.50
# | 에폭 1 |  반복 3841 / 9295 | 시간 386[s] | 퍼플렉서티 202.07
# | 에폭 1 |  반복 3861 / 9295 | 시간 388[s] | 퍼플렉서티 206.16
# | 에폭 1 |  반복 3881 / 9295 | 시간 390[s] | 퍼플렉서티 210.47
# | 에폭 1 |  반복 3901 / 9295 | 시간 392[s] | 퍼플렉서티 210.01
# | 에폭 1 |  반복 3921 / 9295 | 시간 395[s] | 퍼플렉서티 207.41
# | 에폭 1 |  반복 3941 / 9295 | 시간 397[s] | 퍼플렉서티 202.94
# | 에폭 1 |  반복 3961 / 9295 | 시간 399[s] | 퍼플렉서티 158.52
# | 에폭 1 |  반복 3981 / 9295 | 시간 401[s] | 퍼플렉서티 192.84
# | 에폭 1 |  반복 4001 / 9295 | 시간 404[s] | 퍼플렉서티 203.51
# | 에폭 1 |  반복 4021 / 9295 | 시간 406[s] | 퍼플렉서티 181.30
# | 에폭 1 |  반복 4041 / 9295 | 시간 408[s] | 퍼플렉서티 199.92
# | 에폭 1 |  반복 4061 / 9295 | 시간 410[s] | 퍼플렉서티 235.86
# | 에폭 1 |  반복 4081 / 9295 | 시간 412[s] | 퍼플렉서티 262.53
# | 에폭 1 |  반복 4101 / 9295 | 시간 414[s] | 퍼플렉서티 221.81
# | 에폭 1 |  반복 4121 / 9295 | 시간 416[s] | 퍼플렉서티 257.61
# | 에폭 1 |  반복 4141 / 9295 | 시간 418[s] | 퍼플렉서티 253.88
# | 에폭 1 |  반복 4161 / 9295 | 시간 421[s] | 퍼플렉서티 257.40
# | 에폭 1 |  반복 4181 / 9295 | 시간 423[s] | 퍼플렉서티 282.86
# | 에폭 1 |  반복 4201 / 9295 | 시간 425[s] | 퍼플렉서티 261.57
# | 에폭 1 |  반복 4221 / 9295 | 시간 427[s] | 퍼플렉서티 244.76
# | 에폭 1 |  반복 4241 / 9295 | 시간 429[s] | 퍼플렉서티 261.12
# | 에폭 1 |  반복 4261 / 9295 | 시간 431[s] | 퍼플렉서티 236.58
# | 에폭 1 |  반복 4281 / 9295 | 시간 433[s] | 퍼플렉서티 214.27
# | 에폭 1 |  반복 4301 / 9295 | 시간 435[s] | 퍼플렉서티 258.22
# | 에폭 1 |  반복 4321 / 9295 | 시간 437[s] | 퍼플렉서티 261.96
# | 에폭 1 |  반복 4341 / 9295 | 시간 439[s] | 퍼플렉서티 237.45
# | 에폭 1 |  반복 4361 / 9295 | 시간 441[s] | 퍼플렉서티 189.09
# | 에폭 1 |  반복 4381 / 9295 | 시간 443[s] | 퍼플렉서티 193.59
# | 에폭 1 |  반복 4401 / 9295 | 시간 445[s] | 퍼플렉서티 249.41
# | 에폭 1 |  반복 4421 / 9295 | 시간 446[s] | 퍼플렉서티 266.91
# | 에폭 1 |  반복 4441 / 9295 | 시간 448[s] | 퍼플렉서티 228.08
# | 에폭 1 |  반복 4461 / 9295 | 시간 450[s] | 퍼플렉서티 253.33
# | 에폭 1 |  반복 4481 / 9295 | 시간 452[s] | 퍼플렉서티 202.41
# | 에폭 1 |  반복 4501 / 9295 | 시간 454[s] | 퍼플렉서티 198.20
# | 에폭 1 |  반복 4521 / 9295 | 시간 456[s] | 퍼플렉서티 240.61
# | 에폭 1 |  반복 4541 / 9295 | 시간 458[s] | 퍼플렉서티 194.12
# | 에폭 1 |  반복 4561 / 9295 | 시간 460[s] | 퍼플렉서티 205.77
# | 에폭 1 |  반복 4581 / 9295 | 시간 462[s] | 퍼플렉서티 235.20
# | 에폭 1 |  반복 4601 / 9295 | 시간 464[s] | 퍼플렉서티 243.02
# | 에폭 1 |  반복 4621 / 9295 | 시간 466[s] | 퍼플렉서티 209.48
# | 에폭 1 |  반복 4641 / 9295 | 시간 468[s] | 퍼플렉서티 175.33
# | 에폭 1 |  반복 4661 / 9295 | 시간 469[s] | 퍼플렉서티 187.85
# | 에폭 1 |  반복 4681 / 9295 | 시간 472[s] | 퍼플렉서티 150.56
# | 에폭 1 |  반복 4701 / 9295 | 시간 474[s] | 퍼플렉서티 164.03
# | 에폭 1 |  반복 4721 / 9295 | 시간 476[s] | 퍼플렉서티 160.62
# | 에폭 1 |  반복 4741 / 9295 | 시간 478[s] | 퍼플렉서티 183.57
# | 에폭 1 |  반복 4761 / 9295 | 시간 480[s] | 퍼플렉서티 215.48
# | 에폭 1 |  반복 4781 / 9295 | 시간 482[s] | 퍼플렉서티 227.95
# | 에폭 1 |  반복 4801 / 9295 | 시간 484[s] | 퍼플렉서티 226.90
# | 에폭 1 |  반복 4821 / 9295 | 시간 486[s] | 퍼플렉서티 202.02
# | 에폭 1 |  반복 4841 / 9295 | 시간 488[s] | 퍼플렉서티 222.83
# | 에폭 1 |  반복 4861 / 9295 | 시간 489[s] | 퍼플렉서티 158.66
# | 에폭 1 |  반복 4881 / 9295 | 시간 492[s] | 퍼플렉서티 193.97
# | 에폭 1 |  반복 4901 / 9295 | 시간 494[s] | 퍼플렉서티 218.02
# | 에폭 1 |  반복 4921 / 9295 | 시간 496[s] | 퍼플렉서티 201.61
# | 에폭 1 |  반복 4941 / 9295 | 시간 498[s] | 퍼플렉서티 239.02
# | 에폭 1 |  반복 4961 / 9295 | 시간 500[s] | 퍼플렉서티 235.50
# | 에폭 1 |  반복 4981 / 9295 | 시간 502[s] | 퍼플렉서티 209.89
# | 에폭 1 |  반복 5001 / 9295 | 시간 504[s] | 퍼플렉서티 213.69
# | 에폭 1 |  반복 5021 / 9295 | 시간 506[s] | 퍼플렉서티 190.28
# | 에폭 1 |  반복 5041 / 9295 | 시간 507[s] | 퍼플렉서티 223.24
# | 에폭 1 |  반복 5061 / 9295 | 시간 509[s] | 퍼플렉서티 170.95
# | 에폭 1 |  반복 5081 / 9295 | 시간 511[s] | 퍼플렉서티 180.28
# | 에폭 1 |  반복 5101 / 9295 | 시간 513[s] | 퍼플렉서티 164.29
# | 에폭 1 |  반복 5121 / 9295 | 시간 515[s] | 퍼플렉서티 180.48
# | 에폭 1 |  반복 5141 / 9295 | 시간 517[s] | 퍼플렉서티 210.82
# | 에폭 1 |  반복 5161 / 9295 | 시간 519[s] | 퍼플렉서티 197.66
# | 에폭 1 |  반복 5181 / 9295 | 시간 521[s] | 퍼플렉서티 183.17
# | 에폭 1 |  반복 5201 / 9295 | 시간 523[s] | 퍼플렉서티 204.88
# | 에폭 1 |  반복 5221 / 9295 | 시간 525[s] | 퍼플렉서티 189.10
# | 에폭 1 |  반복 5241 / 9295 | 시간 527[s] | 퍼플렉서티 193.34
# | 에폭 1 |  반복 5261 / 9295 | 시간 529[s] | 퍼플렉서티 190.74
# | 에폭 1 |  반복 5281 / 9295 | 시간 531[s] | 퍼플렉서티 175.22
# | 에폭 1 |  반복 5301 / 9295 | 시간 532[s] | 퍼플렉서티 207.09
# | 에폭 1 |  반복 5321 / 9295 | 시간 534[s] | 퍼플렉서티 109.96
# | 에폭 1 |  반복 5341 / 9295 | 시간 536[s] | 퍼플렉서티 169.21
# | 에폭 1 |  반복 5361 / 9295 | 시간 538[s] | 퍼플렉서티 190.83
# | 에폭 1 |  반복 5381 / 9295 | 시간 540[s] | 퍼플렉서티 207.02
# | 에폭 1 |  반복 5401 / 9295 | 시간 542[s] | 퍼플렉서티 172.70
# | 에폭 1 |  반복 5421 / 9295 | 시간 544[s] | 퍼플렉서티 186.08
# | 에폭 1 |  반복 5441 / 9295 | 시간 546[s] | 퍼플렉서티 206.52
# | 에폭 1 |  반복 5461 / 9295 | 시간 548[s] | 퍼플렉서티 168.30
# | 에폭 1 |  반복 5481 / 9295 | 시간 550[s] | 퍼플렉서티 177.53
# | 에폭 1 |  반복 5501 / 9295 | 시간 552[s] | 퍼플렉서티 202.73
# | 에폭 1 |  반복 5521 / 9295 | 시간 554[s] | 퍼플렉서티 238.11
# | 에폭 1 |  반복 5541 / 9295 | 시간 557[s] | 퍼플렉서티 214.34
# | 에폭 1 |  반복 5561 / 9295 | 시간 560[s] | 퍼플렉서티 195.91
# | 에폭 1 |  반복 5581 / 9295 | 시간 563[s] | 퍼플렉서티 214.79
# | 에폭 1 |  반복 5601 / 9295 | 시간 566[s] | 퍼플렉서티 194.91
# | 에폭 1 |  반복 5621 / 9295 | 시간 568[s] | 퍼플렉서티 230.42
# | 에폭 1 |  반복 5641 / 9295 | 시간 570[s] | 퍼플렉서티 223.49
# | 에폭 1 |  반복 5661 / 9295 | 시간 572[s] | 퍼플렉서티 217.65
# | 에폭 1 |  반복 5681 / 9295 | 시간 574[s] | 퍼플렉서티 172.89
# | 에폭 1 |  반복 5701 / 9295 | 시간 576[s] | 퍼플렉서티 150.05
# | 에폭 1 |  반복 5721 / 9295 | 시간 578[s] | 퍼플렉서티 172.81
# | 에폭 1 |  반복 5741 / 9295 | 시간 579[s] | 퍼플렉서티 185.31
# | 에폭 1 |  반복 5761 / 9295 | 시간 581[s] | 퍼플렉서티 198.84
# | 에폭 1 |  반복 5781 / 9295 | 시간 583[s] | 퍼플렉서티 196.52
# | 에폭 1 |  반복 5801 / 9295 | 시간 586[s] | 퍼플렉서티 148.43
# | 에폭 1 |  반복 5821 / 9295 | 시간 588[s] | 퍼플렉서티 177.73
# | 에폭 1 |  반복 5841 / 9295 | 시간 590[s] | 퍼플렉서티 224.38
# | 에폭 1 |  반복 5861 / 9295 | 시간 592[s] | 퍼플렉서티 210.62
# | 에폭 1 |  반복 5881 / 9295 | 시간 594[s] | 퍼플렉서티 224.08
# | 에폭 1 |  반복 5901 / 9295 | 시간 597[s] | 퍼플렉서티 210.73
# | 에폭 1 |  반복 5921 / 9295 | 시간 599[s] | 퍼플렉서티 201.83
# | 에폭 1 |  반복 5941 / 9295 | 시간 602[s] | 퍼플렉서티 182.93
# | 에폭 1 |  반복 5961 / 9295 | 시간 604[s] | 퍼플렉서티 184.02
# | 에폭 1 |  반복 5981 / 9295 | 시간 606[s] | 퍼플렉서티 202.25
# | 에폭 1 |  반복 6001 / 9295 | 시간 608[s] | 퍼플렉서티 206.47
# | 에폭 1 |  반복 6021 / 9295 | 시간 610[s] | 퍼플렉서티 192.60
# | 에폭 1 |  반복 6041 / 9295 | 시간 613[s] | 퍼플렉서티 194.02
# | 에폭 1 |  반복 6061 / 9295 | 시간 614[s] | 퍼플렉서티 200.68
# | 에폭 1 |  반복 6081 / 9295 | 시간 616[s] | 퍼플렉서티 174.12
# | 에폭 1 |  반복 6101 / 9295 | 시간 618[s] | 퍼플렉서티 124.03
# | 에폭 1 |  반복 6121 / 9295 | 시간 620[s] | 퍼플렉서티 189.83
# | 에폭 1 |  반복 6141 / 9295 | 시간 622[s] | 퍼플렉서티 184.46
# | 에폭 1 |  반복 6161 / 9295 | 시간 625[s] | 퍼플렉서티 181.06
# | 에폭 1 |  반복 6181 / 9295 | 시간 627[s] | 퍼플렉서티 191.65
# | 에폭 1 |  반복 6201 / 9295 | 시간 629[s] | 퍼플렉서티 238.98
# | 에폭 1 |  반복 6221 / 9295 | 시간 632[s] | 퍼플렉서티 210.49
# | 에폭 1 |  반복 6241 / 9295 | 시간 634[s] | 퍼플렉서티 248.11
# | 에폭 1 |  반복 6261 / 9295 | 시간 636[s] | 퍼플렉서티 244.93
# | 에폭 1 |  반복 6281 / 9295 | 시간 639[s] | 퍼플렉서티 200.84
# | 에폭 1 |  반복 6301 / 9295 | 시간 641[s] | 퍼플렉서티 202.31
# | 에폭 1 |  반복 6321 / 9295 | 시간 642[s] | 퍼플렉서티 181.53
# | 에폭 1 |  반복 6341 / 9295 | 시간 645[s] | 퍼플렉서티 191.66
# | 에폭 1 |  반복 6361 / 9295 | 시간 647[s] | 퍼플렉서티 186.99
# | 에폭 1 |  반복 6381 / 9295 | 시간 649[s] | 퍼플렉서티 195.46
# | 에폭 1 |  반복 6401 / 9295 | 시간 651[s] | 퍼플렉서티 231.88
# | 에폭 1 |  반복 6421 / 9295 | 시간 652[s] | 퍼플렉서티 207.94
# | 에폭 1 |  반복 6441 / 9295 | 시간 654[s] | 퍼플렉서티 190.13
# | 에폭 1 |  반복 6461 / 9295 | 시간 656[s] | 퍼플렉서티 190.20
# | 에폭 1 |  반복 6481 / 9295 | 시간 658[s] | 퍼플렉서티 171.77
# | 에폭 1 |  반복 6501 / 9295 | 시간 660[s] | 퍼플렉서티 196.71
# | 에폭 1 |  반복 6521 / 9295 | 시간 662[s] | 퍼플렉서티 260.37
# | 에폭 1 |  반복 6541 / 9295 | 시간 664[s] | 퍼플렉서티 262.34
# | 에폭 1 |  반복 6561 / 9295 | 시간 665[s] | 퍼플렉서티 217.74
# | 에폭 1 |  반복 6581 / 9295 | 시간 668[s] | 퍼플렉서티 168.74
# | 에폭 1 |  반복 6601 / 9295 | 시간 669[s] | 퍼플렉서티 188.47
# | 에폭 1 |  반복 6621 / 9295 | 시간 671[s] | 퍼플렉서티 231.43
# | 에폭 1 |  반복 6641 / 9295 | 시간 673[s] | 퍼플렉서티 197.06
# | 에폭 1 |  반복 6661 / 9295 | 시간 675[s] | 퍼플렉서티 202.40
# | 에폭 1 |  반복 6681 / 9295 | 시간 677[s] | 퍼플렉서티 252.26
# | 에폭 1 |  반복 6701 / 9295 | 시간 679[s] | 퍼플렉서티 265.20
# | 에폭 1 |  반복 6721 / 9295 | 시간 681[s] | 퍼플렉서티 226.42
# | 에폭 1 |  반복 6741 / 9295 | 시간 683[s] | 퍼플렉서티 191.91
# | 에폭 1 |  반복 6761 / 9295 | 시간 685[s] | 퍼플렉서티 166.60
# | 에폭 1 |  반복 6781 / 9295 | 시간 687[s] | 퍼플렉서티 243.70
# | 에폭 1 |  반복 6801 / 9295 | 시간 690[s] | 퍼플렉서티 216.57
# | 에폭 1 |  반복 6821 / 9295 | 시간 691[s] | 퍼플렉서티 196.52
# | 에폭 1 |  반복 6841 / 9295 | 시간 693[s] | 퍼플렉서티 190.70
# | 에폭 1 |  반복 6861 / 9295 | 시간 695[s] | 퍼플렉서티 264.22
# | 에폭 1 |  반복 6881 / 9295 | 시간 697[s] | 퍼플렉서티 168.60
# | 에폭 1 |  반복 6901 / 9295 | 시간 699[s] | 퍼플렉서티 189.26
# | 에폭 1 |  반복 6921 / 9295 | 시간 701[s] | 퍼플렉서티 149.62
# | 에폭 1 |  반복 6941 / 9295 | 시간 703[s] | 퍼플렉서티 239.52
# | 에폭 1 |  반복 6961 / 9295 | 시간 705[s] | 퍼플렉서티 147.10
# | 에폭 1 |  반복 6981 / 9295 | 시간 707[s] | 퍼플렉서티 194.91
# | 에폭 1 |  반복 7001 / 9295 | 시간 709[s] | 퍼플렉서티 191.34
# | 에폭 1 |  반복 7021 / 9295 | 시간 711[s] | 퍼플렉서티 217.92
# | 에폭 1 |  반복 7041 / 9295 | 시간 713[s] | 퍼플렉서티 231.06
# | 에폭 1 |  반복 7061 / 9295 | 시간 715[s] | 퍼플렉서티 196.39
# | 에폭 1 |  반복 7081 / 9295 | 시간 717[s] | 퍼플렉서티 219.34
# | 에폭 1 |  반복 7101 / 9295 | 시간 718[s] | 퍼플렉서티 239.88
# | 에폭 1 |  반복 7121 / 9295 | 시간 720[s] | 퍼플렉서티 186.00
# | 에폭 1 |  반복 7141 / 9295 | 시간 722[s] | 퍼플렉서티 176.62
# | 에폭 1 |  반복 7161 / 9295 | 시간 724[s] | 퍼플렉서티 240.69
# | 에폭 1 |  반복 7181 / 9295 | 시간 725[s] | 퍼플렉서티 211.32
# | 에폭 1 |  반복 7201 / 9295 | 시간 727[s] | 퍼플렉서티 223.72
# | 에폭 1 |  반복 7221 / 9295 | 시간 729[s] | 퍼플렉서티 184.75
# | 에폭 1 |  반복 7241 / 9295 | 시간 731[s] | 퍼플렉서티 193.94
# | 에폭 1 |  반복 7261 / 9295 | 시간 733[s] | 퍼플렉서티 166.41
# | 에폭 1 |  반복 7281 / 9295 | 시간 735[s] | 퍼플렉서티 163.77
# | 에폭 1 |  반복 7301 / 9295 | 시간 737[s] | 퍼플렉서티 162.91
# | 에폭 1 |  반복 7321 / 9295 | 시간 739[s] | 퍼플렉서티 151.83
# | 에폭 1 |  반복 7341 / 9295 | 시간 741[s] | 퍼플렉서티 170.67
# | 에폭 1 |  반복 7361 / 9295 | 시간 743[s] | 퍼플렉서티 183.49
# | 에폭 1 |  반복 7381 / 9295 | 시간 745[s] | 퍼플렉서티 209.23
# | 에폭 1 |  반복 7401 / 9295 | 시간 747[s] | 퍼플렉서티 191.56
# | 에폭 1 |  반복 7421 / 9295 | 시간 749[s] | 퍼플렉서티 181.53
# | 에폭 1 |  반복 7441 / 9295 | 시간 751[s] | 퍼플렉서티 159.40
# | 에폭 1 |  반복 7461 / 9295 | 시간 753[s] | 퍼플렉서티 157.39
# | 에폭 1 |  반복 7481 / 9295 | 시간 755[s] | 퍼플렉서티 144.25
# | 에폭 1 |  반복 7501 / 9295 | 시간 757[s] | 퍼플렉서티 131.65
# | 에폭 1 |  반복 7521 / 9295 | 시간 758[s] | 퍼플렉서티 143.15
# | 에폭 1 |  반복 7541 / 9295 | 시간 760[s] | 퍼플렉서티 172.81
# | 에폭 1 |  반복 7561 / 9295 | 시간 762[s] | 퍼플렉서티 154.65
# | 에폭 1 |  반복 7581 / 9295 | 시간 764[s] | 퍼플렉서티 146.88
# | 에폭 1 |  반복 7601 / 9295 | 시간 766[s] | 퍼플렉서티 141.14
# | 에폭 1 |  반복 7621 / 9295 | 시간 768[s] | 퍼플렉서티 172.89
# | 에폭 1 |  반복 7641 / 9295 | 시간 770[s] | 퍼플렉서티 165.90
# | 에폭 1 |  반복 7661 / 9295 | 시간 772[s] | 퍼플렉서티 167.58
# | 에폭 1 |  반복 7681 / 9295 | 시간 774[s] | 퍼플렉서티 181.52
# | 에폭 1 |  반복 7701 / 9295 | 시간 775[s] | 퍼플렉서티 161.61
# | 에폭 1 |  반복 7721 / 9295 | 시간 777[s] | 퍼플렉서티 193.52
# | 에폭 1 |  반복 7741 / 9295 | 시간 779[s] | 퍼플렉서티 219.43
# | 에폭 1 |  반복 7761 / 9295 | 시간 781[s] | 퍼플렉서티 207.16
# | 에폭 1 |  반복 7781 / 9295 | 시간 783[s] | 퍼플렉서티 241.10
# | 에폭 1 |  반복 7801 / 9295 | 시간 785[s] | 퍼플렉서티 203.03
# | 에폭 1 |  반복 7821 / 9295 | 시간 787[s] | 퍼플렉서티 206.35
# | 에폭 1 |  반복 7841 / 9295 | 시간 789[s] | 퍼플렉서티 220.89
# | 에폭 1 |  반복 7861 / 9295 | 시간 791[s] | 퍼플렉서티 204.61
# | 에폭 1 |  반복 7881 / 9295 | 시간 793[s] | 퍼플렉서티 215.07
# | 에폭 1 |  반복 7901 / 9295 | 시간 796[s] | 퍼플렉서티 183.34
# | 에폭 1 |  반복 7921 / 9295 | 시간 798[s] | 퍼플렉서티 156.79
# | 에폭 1 |  반복 7941 / 9295 | 시간 800[s] | 퍼플렉서티 177.44
# | 에폭 1 |  반복 7961 / 9295 | 시간 802[s] | 퍼플렉서티 210.46
# | 에폭 1 |  반복 7981 / 9295 | 시간 804[s] | 퍼플렉서티 216.51
# | 에폭 1 |  반복 8001 / 9295 | 시간 806[s] | 퍼플렉서티 221.98
# | 에폭 1 |  반복 8021 / 9295 | 시간 808[s] | 퍼플렉서티 185.42
# | 에폭 1 |  반복 8041 / 9295 | 시간 809[s] | 퍼플렉서티 166.32
# | 에폭 1 |  반복 8061 / 9295 | 시간 811[s] | 퍼플렉서티 130.08
# | 에폭 1 |  반복 8081 / 9295 | 시간 813[s] | 퍼플렉서티 185.35
# | 에폭 1 |  반복 8101 / 9295 | 시간 815[s] | 퍼플렉서티 209.85
# | 에폭 1 |  반복 8121 / 9295 | 시간 817[s] | 퍼플렉서티 183.20
# | 에폭 1 |  반복 8141 / 9295 | 시간 819[s] | 퍼플렉서티 171.05
# | 에폭 1 |  반복 8161 / 9295 | 시간 821[s] | 퍼플렉서티 159.73
# | 에폭 1 |  반복 8181 / 9295 | 시간 823[s] | 퍼플렉서티 157.45
# | 에폭 1 |  반복 8201 / 9295 | 시간 825[s] | 퍼플렉서티 178.76
# | 에폭 1 |  반복 8221 / 9295 | 시간 827[s] | 퍼플렉서티 188.20
# | 에폭 1 |  반복 8241 / 9295 | 시간 829[s] | 퍼플렉서티 230.56
# | 에폭 1 |  반복 8261 / 9295 | 시간 831[s] | 퍼플렉서티 195.85
# | 에폭 1 |  반복 8281 / 9295 | 시간 832[s] | 퍼플렉서티 166.28
# | 에폭 1 |  반복 8301 / 9295 | 시간 834[s] | 퍼플렉서티 149.95
# | 에폭 1 |  반복 8321 / 9295 | 시간 836[s] | 퍼플렉서티 153.24
# | 에폭 1 |  반복 8341 / 9295 | 시간 838[s] | 퍼플렉서티 165.30
# | 에폭 1 |  반복 8361 / 9295 | 시간 840[s] | 퍼플렉서티 174.02
# | 에폭 1 |  반복 8381 / 9295 | 시간 843[s] | 퍼플렉서티 132.66
# | 에폭 1 |  반복 8401 / 9295 | 시간 844[s] | 퍼플렉서티 130.66
# | 에폭 1 |  반복 8421 / 9295 | 시간 846[s] | 퍼플렉서티 179.56
# | 에폭 1 |  반복 8441 / 9295 | 시간 848[s] | 퍼플렉서티 127.19
# | 에폭 1 |  반복 8461 / 9295 | 시간 850[s] | 퍼플렉서티 148.06
# | 에폭 1 |  반복 8481 / 9295 | 시간 852[s] | 퍼플렉서티 130.48
# | 에폭 1 |  반복 8501 / 9295 | 시간 854[s] | 퍼플렉서티 145.06
# | 에폭 1 |  반복 8521 / 9295 | 시간 856[s] | 퍼플렉서티 148.74
# | 에폭 1 |  반복 8541 / 9295 | 시간 859[s] | 퍼플렉서티 179.70
# | 에폭 1 |  반복 8561 / 9295 | 시간 860[s] | 퍼플렉서티 155.44
# | 에폭 1 |  반복 8581 / 9295 | 시간 862[s] | 퍼플렉서티 161.64
# | 에폭 1 |  반복 8601 / 9295 | 시간 864[s] | 퍼플렉서티 143.73
# | 에폭 1 |  반복 8621 / 9295 | 시간 866[s] | 퍼플렉서티 203.69
# | 에폭 1 |  반복 8641 / 9295 | 시간 869[s] | 퍼플렉서티 184.29
# | 에폭 1 |  반복 8661 / 9295 | 시간 871[s] | 퍼플렉서티 198.17
# | 에폭 1 |  반복 8681 / 9295 | 시간 873[s] | 퍼플렉서티 210.31
# | 에폭 1 |  반복 8701 / 9295 | 시간 875[s] | 퍼플렉서티 163.15
# | 에폭 1 |  반복 8721 / 9295 | 시간 876[s] | 퍼플렉서티 184.51
# | 에폭 1 |  반복 8741 / 9295 | 시간 878[s] | 퍼플렉서티 157.62
# | 에폭 1 |  반복 8761 / 9295 | 시간 880[s] | 퍼플렉서티 169.11
# | 에폭 1 |  반복 8781 / 9295 | 시간 882[s] | 퍼플렉서티 172.41
# | 에폭 1 |  반복 8801 / 9295 | 시간 884[s] | 퍼플렉서티 160.03
# | 에폭 1 |  반복 8821 / 9295 | 시간 886[s] | 퍼플렉서티 174.23
# | 에폭 1 |  반복 8841 / 9295 | 시간 887[s] | 퍼플렉서티 188.20
# | 에폭 1 |  반복 8861 / 9295 | 시간 889[s] | 퍼플렉서티 187.76
# | 에폭 1 |  반복 8881 / 9295 | 시간 891[s] | 퍼플렉서티 142.25
# | 에폭 1 |  반복 8901 / 9295 | 시간 893[s] | 퍼플렉서티 149.19
# | 에폭 1 |  반복 8921 / 9295 | 시간 895[s] | 퍼플렉서티 164.51
# | 에폭 1 |  반복 8941 / 9295 | 시간 897[s] | 퍼플렉서티 167.21
# | 에폭 1 |  반복 8961 / 9295 | 시간 899[s] | 퍼플렉서티 192.83
# | 에폭 1 |  반복 8981 / 9295 | 시간 900[s] | 퍼플렉서티 174.61
# | 에폭 1 |  반복 9001 / 9295 | 시간 902[s] | 퍼플렉서티 212.27
# | 에폭 1 |  반복 9021 / 9295 | 시간 904[s] | 퍼플렉서티 226.09
# | 에폭 1 |  반복 9041 / 9295 | 시간 906[s] | 퍼플렉서티 222.69
# | 에폭 1 |  반복 9061 / 9295 | 시간 908[s] | 퍼플렉서티 221.36
# | 에폭 1 |  반복 9081 / 9295 | 시간 910[s] | 퍼플렉서티 246.28
# | 에폭 1 |  반복 9101 / 9295 | 시간 911[s] | 퍼플렉서티 222.03
# | 에폭 1 |  반복 9121 / 9295 | 시간 913[s] | 퍼플렉서티 232.45
# | 에폭 1 |  반복 9141 / 9295 | 시간 915[s] | 퍼플렉서티 174.32
# | 에폭 1 |  반복 9161 / 9295 | 시간 917[s] | 퍼플렉서티 223.70
# | 에폭 1 |  반복 9181 / 9295 | 시간 919[s] | 퍼플렉서티 190.92
# | 에폭 1 |  반복 9201 / 9295 | 시간 921[s] | 퍼플렉서티 210.75
# | 에폭 1 |  반복 9221 / 9295 | 시간 922[s] | 퍼플렉서티 230.35
# | 에폭 1 |  반복 9241 / 9295 | 시간 924[s] | 퍼플렉서티 216.10
# | 에폭 1 |  반복 9261 / 9295 | 시간 926[s] | 퍼플렉서티 212.00
# | 에폭 1 |  반복 9281 / 9295 | 시간 928[s] | 퍼플렉서티 216.47

# %%
import sys
def eval_perplexity(model, corpus, batch_size=10, time_size=35):
    print('퍼플렉서티 평가 중 ...')
    corpus_size = len(corpus)
    total_loss, loss_cnt = 0, 0
    max_iters = (corpus_size - 1) // (batch_size * time_size)
    jump = (corpus_size - 1) // batch_size

    for iters in range(max_iters):
        xs = np.zeros((batch_size, time_size), dtype=np.int32)
        ts = np.zeros((batch_size, time_size), dtype=np.int32)
        time_offset = iters * time_size
        offsets = [time_offset + (i * jump) for i in range(batch_size)]
        for t in range(time_size):
            for i, offset in enumerate(offsets):
                xs[i, t] = corpus[(offset + t) % corpus_size]
                ts[i, t] = corpus[(offset + t + 1) % corpus_size]

        try:
            loss = model.forward(xs, ts, train_flg=False)
        except TypeError:
            loss = model.forward(xs, ts)
        total_loss += loss

        sys.stdout.write('\r%d / %d' % (iters, max_iters))
        sys.stdout.flush()

    print('')
    ppl = np.exp(total_loss / max_iters)
    return ppl

# %%
# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)  # test 데이터로 평가
print('테스트 퍼플렉서티: ', ppl_test)

# 매개변수 저장
model.save_params()
# Out:
# 퍼플렉서티 평가 중 ...
# 234 / 235
# 테스트 퍼플렉서티:  205.12711264803895

# %% [markdown]
# ### 개선된 RNNLM 구현

# %%
# [1] LSTM을 2층으로 구현
# [2] 가중치를 공유
# [3] Dropout사용

class BetterRnnlm():
    def __init__(self,vocab_size, wordvec_size, hidden_size,dropout_ratio=0.5):
        V,D,H = vocab_size, wordvec_size,hidden_size   # 10000, 100,100
        rn = np.random.randn
        
        # 가중치 초기화
        embed_W = (rn(V,D)/100).astype('f')      # Affine 계층과 가중치 공유
        
        lstm_Wx1 = (rn(D,4*H) / np.sqrt(D)).astype('f')  # Wx1 : (D,4*H)
        lstm_Wh1 = (rn(H,4*H) / np.sqrt(H)).astype('f')
        lstm_b1 = np.zeros(4*H).astype('f')

        lstm_Wx2 = (rn(H,4*H) / np.sqrt(H)).astype('f')  # Wx2: (H,4*H)
        lstm_Wh2 = (rn(H,4*H) / np.sqrt(H)).astype('f')
        lstm_b2 = np.zeros(4*H).astype('f')
        
        # affine_W = (rn(H,V) / np.sqrt(H)).astype('f') # 사용하지 않음
        affine_b = np.zeros(V).astype('f')
        
        # 계층 생성
        self.layers = [
            TimeEmbedding(embed_W),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx1,lstm_Wh1,lstm_b1,stateful=True),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx2,lstm_Wh2,lstm_b2,stateful=True),
            TimeDropout(dropout_ratio),
            TimeAffine(embed_W.T,affine_b)  # embed_W.T : (D,V), D=H=650 이므로 (H,V)와 같음, weight tying!!        
            
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layers = [self.layers[2],self.layers[4]]
        self.drop_layers = [self.layers[1],self.layers[3],self.layers[5]]
        
        # 모든 가중치와 기울기를 리스트에 모은다.
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads        

    def predict(self,xs, train_flag=False): 
        for layer in self.drop_layers: # 예측 시에는 dropout을 사용하지 않도록 플래그를 설정
            layer.train_flag = train_flag  
        
        for layer in self.layers:      # 7회 반복
             xs = layer.forward(xs)
        return xs        
            
    def forward(self,xs,ts, train_flag=True):
        score = self.predict(xs, train_flag) # 학습 시에는 dropout을 사용하도록 플래그를 설정
        loss = self.loss_layer.forward(score,ts)
        return loss
    
    def backward(self,dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers): # 7회
            dout = layer.backward(dout)
        return dout
    
    def reset_state(self):
        for layer in self.lstm_layers: # 2회
            layer.reset_state()
        
    def save_params(self, file_name='BetterRnnlm.pkl'):
        with open(file_name,'wb') as f:
            pickle.dump(self.params,f)
            
    def load_params(self, file_name='BetterRnnlm.pkl'):
        with open(file_name,'rb') as f:
            self.params = pickle.load(f)

# %%
# TimeDropout 클래스
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout
# dropout 된 입력 데이터는 0이 된다
# dropout 되지 않은 입력 데이터는  1/(1 - rate)을 곱하여 scale up 시킨다 (droput rate:0~1)

# nn_layers.py에 추가

class TimeDropout:
    def __init__(self, dropout_ratio=0.5):
        self.params,self.grads = [],[]
        self.dropout_ratio = dropout_ratio
        self.mask = None
        self.train_flg = True   # 학습시에만 True로 설정하여 dropout 적용, 예측시에는 사용하지 않음
        
    def forward(self,xs):
        if self.train_flg:
            flg = np.random.rand(*xs.shape) > self.dropout_ratio            
            scale = 1 / (1.0 - self.dropout_ratio)
            self.mask = flg.astype(np.float32) * scale

            return xs * self.mask
        else:
            return xs
            
    def backward(self, dout):
        return dout * self.mask

# %%
dropout_ratio = 0.5
dr = TimeDropout(dropout_ratio)

xs = np.arange(1,10).reshape(3,3)
print('xs:\n',xs)

# dr.train_flg = True
drop_xs = dr.forward(xs)
print('drop_xs:\n',drop_xs)

print('-'*30)
flg = np.random.rand(*xs.shape) > dropout_ratio    
print('flg:\n',flg)
print(xs*flg)
# Out:
# xs:
#  [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
# drop_xs:
#  [[ 0.  4.  0.]
#  [ 8.  0. 12.]
#  [14.  0.  0.]]
# ------------------------------
# flg:
#  [[ True False  True]
#  [False False False]
#  [False False False]]
# [[1 0 3]
#  [0 0 0]
#  [0 0 0]]
